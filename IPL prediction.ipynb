# %% [markdown]
# ### Installing libraries and loading data

# %%
import numpy as np
import pandas as pd

import warnings

# Ignore all warnings
warnings.filterwarnings("ignore")

# %%
# !pip install scikit-learn==1.5.1
# Out:
# Requirement already satisfied: scikit-learn==1.5.1 in c:\users\shilpi singh\anaconda3\lib\site-packages (1.5.1)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\shilpi singh\anaconda3\lib\site-packages (from scikit-learn==1.5.1) (1.20.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\shilpi singh\anaconda3\lib\site-packages (from scikit-learn==1.5.1) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\shilpi singh\anaconda3\lib\site-packages (from scikit-learn==1.5.1) (3.5.0)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\shilpi singh\anaconda3\lib\site-packages (from scikit-learn==1.5.1) (1.7.1)

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.5.1

# %%
match = pd.read_csv('matches.csv')
delivery = pd.read_csv('deliveries.csv')

# %%
match.head()
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# 0        Kolkata Knight Riders  Royal Challengers Bangalore         field
# 1          Chennai Super Kings          Chennai Super Kings           bat
# 2             Rajasthan Royals             Rajasthan Royals           bat
# 3  Royal Challengers Bangalore               Mumbai Indians           bat
# 4              Deccan Chargers              Deccan Chargers           bat
#
#                         winner   result  result_margin  target_runs  \
# 0        Kolkata Knight Riders     runs          140.0        223.0
# 1          Chennai Super Kings     runs           33.0        241.0
# 2             Delhi Daredevils  wickets            9.0        130.0
# 3  Royal Challengers Bangalore  wickets            5.0        166.0
# 4        Kolkata Knight Riders  wickets            5.0        111.0
#
#    target_overs super_over method    umpire1         umpire2
# 0          20.0          N    NaN  Asad Rauf     RE Koertzen
# 1          20.0          N    NaN  MR Benson      SL Shastri
# 2          20.0          N    NaN  Aleem Dar  GA Pratapkumar
# 3          20.0          N    NaN   SJ Davis       DJ Harper
# 4          20.0          N    NaN  BF Bowden     K Hariharan

# %%
match.shape
# Out:
# (1095, 20)

# %%
delivery.head()
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
# 2     3  BB McCullum  P Kumar   SC Ganguly             0           1
# 3     4  BB McCullum  P Kumar   SC Ganguly             0           0
# 4     5  BB McCullum  P Kumar   SC Ganguly             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# 0           1     legbyes          0              NaN            NaN     NaN
# 1           0         NaN          0              NaN            NaN     NaN
# 2           1       wides          0              NaN            NaN     NaN
# 3           0         NaN          0              NaN            NaN     NaN
# 4           0         NaN          0              NaN            NaN     NaN

# %% [markdown]
# ### checking valid current teams

# %%
match['team1'].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Mumbai Indians', 'Kolkata Knight Riders',
#        'Rajasthan Royals', 'Deccan Chargers', 'Chennai Super Kings',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
#        'Gujarat Lions', 'Rising Pune Supergiants',
#        'Rising Pune Supergiant', 'Delhi Capitals', 'Punjab Kings',
#        'Lucknow Super Giants', 'Gujarat Titans',
#        'Royal Challengers Bengaluru'], dtype=object)

# %%
#Total teams name which play the IPL match currently are given below:
teams = [
    'Sunrisers Hyderabad',
    'Mumbai Indians',
    'Royal Challengers Bangalore',
    'Kolkata Knight Riders',
    'Kings XI Punjab',
    'Chennai Super Kings',
    'Rajasthan Royals',
    'Delhi Capitals'
]

# %%
# There are two teams which is being renamed. So will replace the old team name with the new one.
match['team1'] = match['team1'].str.replace('Delhi Daredevils','Delhi Capitals')
match['team2'] = match['team2'].str.replace('Delhi Daredevils','Delhi Capitals')

match['team1'] = match['team1'].str.replace('Deccan Chargers','Sunrisers Hyderabad')
match['team2'] = match['team2'].str.replace('Deccan Chargers','Sunrisers Hyderabad')

# %%
#We can see there are few teams which does not play now in the IPL. So we will not consider those teams in our analysis.
match = match[match['team1'].isin(teams)]
match = match[match['team2'].isin(teams)]

# %%
match.shape
# Out:
# (839, 20)

# %%
#We will be needing only few rows from the match dataframe.

match_df = match[['id','city','winner','target_runs']]

# %%
match_df.head()
# Out:
#        id        city                       winner  target_runs
# 0  335982   Bangalore        Kolkata Knight Riders        223.0
# 1  335983  Chandigarh          Chennai Super Kings        241.0
# 2  335984       Delhi             Delhi Daredevils        130.0
# 3  335985      Mumbai  Royal Challengers Bangalore        166.0
# 4  335986     Kolkata        Kolkata Knight Riders        111.0

# %%
#we will merge the new match dataframe with the delivery dataframe
delivery_df = match_df.merge(delivery,left_on='id',right_on='match_id')

# %%
delivery_df
# Out:
#              id       city                 winner  target_runs  match_id  \
# 0        335982  Bangalore  Kolkata Knight Riders        223.0    335982
# 1        335982  Bangalore  Kolkata Knight Riders        223.0    335982
# 2        335982  Bangalore  Kolkata Knight Riders        223.0    335982
# 3        335982  Bangalore  Kolkata Knight Riders        223.0    335982
# 4        335982  Bangalore  Kolkata Knight Riders        223.0    335982
# ...         ...        ...                    ...          ...       ...
# 199873  1426312    Chennai  Kolkata Knight Riders        114.0   1426312
# 199874  1426312    Chennai  Kolkata Knight Riders        114.0   1426312
# 199875  1426312    Chennai  Kolkata Knight Riders        114.0   1426312
# 199876  1426312    Chennai  Kolkata Knight Riders        114.0   1426312
# 199877  1426312    Chennai  Kolkata Knight Riders        114.0   1426312
#
#         inning           batting_team                 bowling_team  over  \
# 0            1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1            1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2            1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3            1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4            1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# ...        ...                    ...                          ...   ...
# 199873       2  Kolkata Knight Riders          Sunrisers Hyderabad     9
# 199874       2  Kolkata Knight Riders          Sunrisers Hyderabad     9
# 199875       2  Kolkata Knight Riders          Sunrisers Hyderabad    10
# 199876       2  Kolkata Knight Riders          Sunrisers Hyderabad    10
# 199877       2  Kolkata Knight Riders          Sunrisers Hyderabad    10
#
#         ball  ...         bowler  non_striker batsman_runs  extra_runs  \
# 0          1  ...        P Kumar  BB McCullum            0           1
# 1          2  ...        P Kumar   SC Ganguly            0           0
# 2          3  ...        P Kumar   SC Ganguly            0           1
# 3          4  ...        P Kumar   SC Ganguly            0           0
# 4          5  ...        P Kumar   SC Ganguly            0           0
# ...      ...  ...            ...          ...          ...         ...
# 199873     5  ...     AK Markram      VR Iyer            1           0
# 199874     6  ...     AK Markram      SS Iyer            1           0
# 199875     1  ...  Shahbaz Ahmed      SS Iyer            1           0
# 199876     2  ...  Shahbaz Ahmed      VR Iyer            1           0
# 199877     3  ...  Shahbaz Ahmed      SS Iyer            1           0
#
#         total_runs  extras_type is_wicket  player_dismissed dismissal_kind  \
# 0                1      legbyes         0               NaN            NaN
# 1                0          NaN         0               NaN            NaN
# 2                1        wides         0               NaN            NaN
# 3                0          NaN         0               NaN            NaN
# 4                0          NaN         0               NaN            NaN
# ...            ...          ...       ...               ...            ...
# 199873           1          NaN         0               NaN            NaN
# 199874           1          NaN         0               NaN            NaN
# 199875           1          NaN         0               NaN            NaN
# 199876           1          NaN         0               NaN            NaN
# 199877           1          NaN         0               NaN            NaN
#
#        fielder
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ...        ...
# 199873     NaN
# 199874     NaN
# 199875     NaN
# 199876     NaN
# 199877     NaN
#
# [199878 rows x 21 columns]

# %% [markdown]
# ### Data pre-processing after one inning has been played

# %%
#we need to analyse for the second inning only.
delivery_df = delivery_df[delivery_df['inning'] == 2]

# %%
delivery_df.drop('match_id',axis=1,inplace=True)

# %%
delivery_df.rename(columns={'id': 'match_id'}, inplace=True)

# %%
delivery_df
# Out:
#         match_id       city                 winner  target_runs  inning  \
# 124       335982  Bangalore  Kolkata Knight Riders        223.0       2
# 125       335982  Bangalore  Kolkata Knight Riders        223.0       2
# 126       335982  Bangalore  Kolkata Knight Riders        223.0       2
# 127       335982  Bangalore  Kolkata Knight Riders        223.0       2
# 128       335982  Bangalore  Kolkata Knight Riders        223.0       2
# ...          ...        ...                    ...          ...     ...
# 199873   1426312    Chennai  Kolkata Knight Riders        114.0       2
# 199874   1426312    Chennai  Kolkata Knight Riders        114.0       2
# 199875   1426312    Chennai  Kolkata Knight Riders        114.0       2
# 199876   1426312    Chennai  Kolkata Knight Riders        114.0       2
# 199877   1426312    Chennai  Kolkata Knight Riders        114.0       2
#
#                        batting_team           bowling_team  over  ball  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders     0     1
# 125     Royal Challengers Bangalore  Kolkata Knight Riders     0     2
# 126     Royal Challengers Bangalore  Kolkata Knight Riders     0     3
# 127     Royal Challengers Bangalore  Kolkata Knight Riders     0     4
# 128     Royal Challengers Bangalore  Kolkata Knight Riders     0     5
# ...                             ...                    ...   ...   ...
# 199873        Kolkata Knight Riders    Sunrisers Hyderabad     9     5
# 199874        Kolkata Knight Riders    Sunrisers Hyderabad     9     6
# 199875        Kolkata Knight Riders    Sunrisers Hyderabad    10     1
# 199876        Kolkata Knight Riders    Sunrisers Hyderabad    10     2
# 199877        Kolkata Knight Riders    Sunrisers Hyderabad    10     3
#
#           batter         bowler non_striker  batsman_runs  extra_runs  \
# 124     R Dravid       AB Dinda    W Jaffer             1           0
# 125     W Jaffer       AB Dinda    R Dravid             0           1
# 126     W Jaffer       AB Dinda    R Dravid             0           0
# 127     W Jaffer       AB Dinda    R Dravid             1           0
# 128     R Dravid       AB Dinda    W Jaffer             1           0
# ...          ...            ...         ...           ...         ...
# 199873   SS Iyer     AK Markram     VR Iyer             1           0
# 199874   VR Iyer     AK Markram     SS Iyer             1           0
# 199875   VR Iyer  Shahbaz Ahmed     SS Iyer             1           0
# 199876   SS Iyer  Shahbaz Ahmed     VR Iyer             1           0
# 199877   VR Iyer  Shahbaz Ahmed     SS Iyer             1           0
#
#         total_runs extras_type  is_wicket player_dismissed dismissal_kind  \
# 124              1         NaN          0              NaN            NaN
# 125              1       wides          0              NaN            NaN
# 126              0         NaN          0              NaN            NaN
# 127              1         NaN          0              NaN            NaN
# 128              1         NaN          0              NaN            NaN
# ...            ...         ...        ...              ...            ...
# 199873           1         NaN          0              NaN            NaN
# 199874           1         NaN          0              NaN            NaN
# 199875           1         NaN          0              NaN            NaN
# 199876           1         NaN          0              NaN            NaN
# 199877           1         NaN          0              NaN            NaN
#
#        fielder
# 124        NaN
# 125        NaN
# 126        NaN
# 127        NaN
# 128        NaN
# ...        ...
# 199873     NaN
# 199874     NaN
# 199875     NaN
# 199876     NaN
# 199877     NaN
#
# [96385 rows x 20 columns]

# %%
# We will calculate the total runs scored after each ball.
delivery_df['current_score'] = delivery_df.groupby('match_id').cumsum()['total_runs']

# %%
# Lets calculate total run left after each ball.
delivery_df['runs_left'] = delivery_df['target_runs'] - delivery_df['current_score']

# %%
# Now lets calculate the total balls left
delivery_df['balls_left'] = 120 - (delivery_df['over']*6 + delivery_df['ball'])

# %%
delivery_df
# Out:
#         match_id       city                 winner  target_runs  inning  \
# 124       335982  Bangalore  Kolkata Knight Riders        223.0       2
# 125       335982  Bangalore  Kolkata Knight Riders        223.0       2
# 126       335982  Bangalore  Kolkata Knight Riders        223.0       2
# 127       335982  Bangalore  Kolkata Knight Riders        223.0       2
# 128       335982  Bangalore  Kolkata Knight Riders        223.0       2
# ...          ...        ...                    ...          ...     ...
# 199873   1426312    Chennai  Kolkata Knight Riders        114.0       2
# 199874   1426312    Chennai  Kolkata Knight Riders        114.0       2
# 199875   1426312    Chennai  Kolkata Knight Riders        114.0       2
# 199876   1426312    Chennai  Kolkata Knight Riders        114.0       2
# 199877   1426312    Chennai  Kolkata Knight Riders        114.0       2
#
#                        batting_team           bowling_team  over  ball  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders     0     1
# 125     Royal Challengers Bangalore  Kolkata Knight Riders     0     2
# 126     Royal Challengers Bangalore  Kolkata Knight Riders     0     3
# 127     Royal Challengers Bangalore  Kolkata Knight Riders     0     4
# 128     Royal Challengers Bangalore  Kolkata Knight Riders     0     5
# ...                             ...                    ...   ...   ...
# 199873        Kolkata Knight Riders    Sunrisers Hyderabad     9     5
# 199874        Kolkata Knight Riders    Sunrisers Hyderabad     9     6
# 199875        Kolkata Knight Riders    Sunrisers Hyderabad    10     1
# 199876        Kolkata Knight Riders    Sunrisers Hyderabad    10     2
# 199877        Kolkata Knight Riders    Sunrisers Hyderabad    10     3
#
#           batter  ... extra_runs total_runs  extras_type  is_wicket  \
# 124     R Dravid  ...          0          1          NaN          0
# 125     W Jaffer  ...          1          1        wides          0
# 126     W Jaffer  ...          0          0          NaN          0
# 127     W Jaffer  ...          0          1          NaN          0
# 128     R Dravid  ...          0          1          NaN          0
# ...          ...  ...        ...        ...          ...        ...
# 199873   SS Iyer  ...          0          1          NaN          0
# 199874   VR Iyer  ...          0          1          NaN          0
# 199875   VR Iyer  ...          0          1          NaN          0
# 199876   SS Iyer  ...          0          1          NaN          0
# 199877   VR Iyer  ...          0          1          NaN          0
#
#         player_dismissed dismissal_kind  fielder current_score runs_left  \
# 124                  NaN            NaN      NaN             1     222.0
# 125                  NaN            NaN      NaN             2     221.0
# 126                  NaN            NaN      NaN             2     221.0
# 127                  NaN            NaN      NaN             3     220.0
# 128                  NaN            NaN      NaN             4     219.0
# ...                  ...            ...      ...           ...       ...
# 199873               NaN            NaN      NaN           110       4.0
# 199874               NaN            NaN      NaN           111       3.0
# 199875               NaN            NaN      NaN           112       2.0
# 199876               NaN            NaN      NaN           113       1.0
# 199877               NaN            NaN      NaN           114       0.0
#
#        balls_left
# 124           119
# 125           118
# 126           117
# 127           116
# 128           115
# ...           ...
# 199873         61
# 199874         60
# 199875         59
# 199876         58
# 199877         57
#
# [96385 rows x 23 columns]

# %%
# We will calculate the wickets left after every wicket.
wickets = delivery_df.groupby('match_id').cumsum()['is_wicket'].values
delivery_df['wickets_left'] = 10 - wickets

# %%
delivery_df
# Out:
#         match_id       city                 winner  target_runs  inning  \
# 124       335982  Bangalore  Kolkata Knight Riders        223.0       2
# 125       335982  Bangalore  Kolkata Knight Riders        223.0       2
# 126       335982  Bangalore  Kolkata Knight Riders        223.0       2
# 127       335982  Bangalore  Kolkata Knight Riders        223.0       2
# 128       335982  Bangalore  Kolkata Knight Riders        223.0       2
# ...          ...        ...                    ...          ...     ...
# 199873   1426312    Chennai  Kolkata Knight Riders        114.0       2
# 199874   1426312    Chennai  Kolkata Knight Riders        114.0       2
# 199875   1426312    Chennai  Kolkata Knight Riders        114.0       2
# 199876   1426312    Chennai  Kolkata Knight Riders        114.0       2
# 199877   1426312    Chennai  Kolkata Knight Riders        114.0       2
#
#                        batting_team           bowling_team  over  ball  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders     0     1
# 125     Royal Challengers Bangalore  Kolkata Knight Riders     0     2
# 126     Royal Challengers Bangalore  Kolkata Knight Riders     0     3
# 127     Royal Challengers Bangalore  Kolkata Knight Riders     0     4
# 128     Royal Challengers Bangalore  Kolkata Knight Riders     0     5
# ...                             ...                    ...   ...   ...
# 199873        Kolkata Knight Riders    Sunrisers Hyderabad     9     5
# 199874        Kolkata Knight Riders    Sunrisers Hyderabad     9     6
# 199875        Kolkata Knight Riders    Sunrisers Hyderabad    10     1
# 199876        Kolkata Knight Riders    Sunrisers Hyderabad    10     2
# 199877        Kolkata Knight Riders    Sunrisers Hyderabad    10     3
#
#           batter  ... total_runs extras_type  is_wicket  player_dismissed  \
# 124     R Dravid  ...          1         NaN          0               NaN
# 125     W Jaffer  ...          1       wides          0               NaN
# 126     W Jaffer  ...          0         NaN          0               NaN
# 127     W Jaffer  ...          1         NaN          0               NaN
# 128     R Dravid  ...          1         NaN          0               NaN
# ...          ...  ...        ...         ...        ...               ...
# 199873   SS Iyer  ...          1         NaN          0               NaN
# 199874   VR Iyer  ...          1         NaN          0               NaN
# 199875   VR Iyer  ...          1         NaN          0               NaN
# 199876   SS Iyer  ...          1         NaN          0               NaN
# 199877   VR Iyer  ...          1         NaN          0               NaN
#
#         dismissal_kind fielder  current_score runs_left balls_left  \
# 124                NaN     NaN              1     222.0        119
# 125                NaN     NaN              2     221.0        118
# 126                NaN     NaN              2     221.0        117
# 127                NaN     NaN              3     220.0        116
# 128                NaN     NaN              4     219.0        115
# ...                ...     ...            ...       ...        ...
# 199873             NaN     NaN            110       4.0         61
# 199874             NaN     NaN            111       3.0         60
# 199875             NaN     NaN            112       2.0         59
# 199876             NaN     NaN            113       1.0         58
# 199877             NaN     NaN            114       0.0         57
#
#        wickets_left
# 124              10
# 125              10
# 126              10
# 127              10
# 128              10
# ...             ...
# 199873            8
# 199874            8
# 199875            8
# 199876            8
# 199877            8
#
# [96385 rows x 24 columns]

# %%
# current run rate(crr) = runs/overs
delivery_df['crr'] = (delivery_df['current_score']*6)/(120 - delivery_df['balls_left'])

# %%
#required run rate(rrr)=runs left/over
delivery_df['rrr'] = (delivery_df['runs_left']*6)/delivery_df['balls_left']

# %%
# we will create a function result to store the value after checking if the batting team wins the match
def result(row):
    return 1 if row['batting_team'] == row['winner'] else 0

# %%
delivery_df['result'] = delivery_df.apply(result,axis=1)

# %%
delivery_df
# Out:
#         match_id       city                 winner  target_runs  inning  \
# 124       335982  Bangalore  Kolkata Knight Riders        223.0       2
# 125       335982  Bangalore  Kolkata Knight Riders        223.0       2
# 126       335982  Bangalore  Kolkata Knight Riders        223.0       2
# 127       335982  Bangalore  Kolkata Knight Riders        223.0       2
# 128       335982  Bangalore  Kolkata Knight Riders        223.0       2
# ...          ...        ...                    ...          ...     ...
# 199873   1426312    Chennai  Kolkata Knight Riders        114.0       2
# 199874   1426312    Chennai  Kolkata Knight Riders        114.0       2
# 199875   1426312    Chennai  Kolkata Knight Riders        114.0       2
# 199876   1426312    Chennai  Kolkata Knight Riders        114.0       2
# 199877   1426312    Chennai  Kolkata Knight Riders        114.0       2
#
#                        batting_team           bowling_team  over  ball  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders     0     1
# 125     Royal Challengers Bangalore  Kolkata Knight Riders     0     2
# 126     Royal Challengers Bangalore  Kolkata Knight Riders     0     3
# 127     Royal Challengers Bangalore  Kolkata Knight Riders     0     4
# 128     Royal Challengers Bangalore  Kolkata Knight Riders     0     5
# ...                             ...                    ...   ...   ...
# 199873        Kolkata Knight Riders    Sunrisers Hyderabad     9     5
# 199874        Kolkata Knight Riders    Sunrisers Hyderabad     9     6
# 199875        Kolkata Knight Riders    Sunrisers Hyderabad    10     1
# 199876        Kolkata Knight Riders    Sunrisers Hyderabad    10     2
# 199877        Kolkata Knight Riders    Sunrisers Hyderabad    10     3
#
#           batter  ... player_dismissed dismissal_kind  fielder  current_score  \
# 124     R Dravid  ...              NaN            NaN      NaN              1
# 125     W Jaffer  ...              NaN            NaN      NaN              2
# 126     W Jaffer  ...              NaN            NaN      NaN              2
# 127     W Jaffer  ...              NaN            NaN      NaN              3
# 128     R Dravid  ...              NaN            NaN      NaN              4
# ...          ...  ...              ...            ...      ...            ...
# 199873   SS Iyer  ...              NaN            NaN      NaN            110
# 199874   VR Iyer  ...              NaN            NaN      NaN            111
# 199875   VR Iyer  ...              NaN            NaN      NaN            112
# 199876   SS Iyer  ...              NaN            NaN      NaN            113
# 199877   VR Iyer  ...              NaN            NaN      NaN            114
#
#         runs_left balls_left  wickets_left        crr        rrr result
# 124         222.0        119            10   6.000000  11.193277      0
# 125         221.0        118            10   6.000000  11.237288      0
# 126         221.0        117            10   4.000000  11.333333      0
# 127         220.0        116            10   4.500000  11.379310      0
# 128         219.0        115            10   4.800000  11.426087      0
# ...           ...        ...           ...        ...        ...    ...
# 199873        4.0         61             8  11.186441   0.393443      1
# 199874        3.0         60             8  11.100000   0.300000      1
# 199875        2.0         59             8  11.016393   0.203390      1
# 199876        1.0         58             8  10.935484   0.103448      1
# 199877        0.0         57             8  10.857143   0.000000      1
#
# [96385 rows x 27 columns]

# %% [markdown]
# ## creating Final dataframe

# %%
final_df = delivery_df[['batting_team','bowling_team','city','runs_left','balls_left','wickets_left','target_runs','crr','rrr','result']]

# %%
# lets shuffle the rows to build the model accurately

final_df = final_df.sample(final_df.shape[0])

# %%
final_df
# Out:
#                batting_team           bowling_team        city  runs_left  \
# 62659   Chennai Super Kings       Delhi Daredevils     Chennai      113.0
# 27841      Delhi Daredevils        Kings XI Punjab  Chandigarh       10.0
# 185334     Rajasthan Royals    Chennai Super Kings      Mumbai       79.0
# 50304      Delhi Daredevils        Kings XI Punjab  Dharamsala       96.0
# 122561       Mumbai Indians        Kings XI Punjab      Mumbai       28.0
# ...                     ...                    ...         ...        ...
# 136692  Chennai Super Kings        Kings XI Punjab        Pune       93.0
# 103100     Delhi Daredevils       Rajasthan Royals      Mumbai      170.0
# 50248      Delhi Daredevils        Kings XI Punjab  Dharamsala      156.0
# 69567   Sunrisers Hyderabad  Kolkata Knight Riders     Kolkata       49.0
# 82781   Sunrisers Hyderabad        Kings XI Punjab         NaN      133.0
#
#         balls_left  wickets_left  target_runs        crr         rrr  result
# 62659          114            10        115.0   2.000000    5.947368       1
# 27841            8             6        143.0   7.125000    7.500000       1
# 185334          62             8        151.0   7.448276    7.645161       1
# 50304           47             7        171.0   6.164384   12.255319       0
# 122561          15             5        231.0  11.600000   11.200000       0
# ...            ...           ...          ...        ...         ...     ...
# 136692          56             6        154.0   5.718750    9.964286       1
# 103100         105             9        190.0   8.000000    9.714286       0
# 50248          102            10        171.0   5.000000    9.176471       0
# 69567           -1             3        181.0   6.545455 -294.000000       0
# 82781           68             6        194.0   7.038462   11.735294       0
#
# [96385 rows x 10 columns]

# %%
final_df.sample()
# Out:
#           batting_team           bowling_team       city  runs_left  \
# 123374  Mumbai Indians  Kolkata Knight Riders  Bangalore       78.0
#
#         balls_left  wickets_left  target_runs  crr    rrr  result
# 123374          96             8        108.0  7.5  4.875       1

# %%
#lets check the null values in the final data frame
final_df.isnull().sum()
# Out:
# batting_team       0
# bowling_team       0
# city            6012
# runs_left          0
# balls_left         0
# wickets_left       0
# target_runs        0
# crr                0
# rrr               12
# result             0
# dtype: int64

# %%
# we will drop the rows where the value is null.
final_df.dropna(inplace=True)

# %%
final_df.describe()
# Out:
#           runs_left    balls_left  wickets_left   target_runs           crr  \
# count  90361.000000  90361.000000  90361.000000  90361.000000  90361.000000
# mean      93.308352     62.863492      7.531258    167.051958      7.529250
# std       50.599661     33.408582      2.151726     30.991279      2.338339
# min      -10.000000     -2.000000      0.000000     43.000000      0.000000
# 25%       53.000000     35.000000      6.000000    148.000000      6.333333
# 50%       92.000000     64.000000      8.000000    166.000000      7.546392
# 75%      131.000000     92.000000      9.000000    187.000000      8.756757
# max      278.000000    119.000000     10.000000    278.000000     36.000000
#
#                 rrr        result
# count  9.036100e+04  90361.000000
# mean            NaN      0.519749
# std             NaN      0.499613
# min            -inf      0.000000
# 25%    7.180328e+00      0.000000
# 50%    8.940000e+00      1.000000
# 75%    1.114286e+01      1.000000
# max             inf      1.000000

# %%
# From the above descrption we can see that there are values as infinite and -infinite in the rrr column. So we will be looking fot the data where the balls_left is not 0.

final_df = final_df[final_df['balls_left'] != 0]

# %% [markdown]
# ### Splitting the data into train and test set

# %%
# X will have all rows and all columns except the result and Y will have all rows and only result column

X = final_df.iloc[:,:-1]
y = final_df.iloc[:,-1]


from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
X_train
# Out:
#                        batting_team                 bowling_team        city  \
# 128264             Rajasthan Royals               Mumbai Indians      Jaipur
# 189548             Rajasthan Royals  Royal Challengers Bangalore   Bengaluru
# 100819              Kings XI Punjab          Chennai Super Kings     Chennai
# 108772        Kolkata Knight Riders             Delhi Daredevils     Kolkata
# 97148              Rajasthan Royals               Mumbai Indians   Ahmedabad
# ...                             ...                          ...         ...
# 118803              Kings XI Punjab          Sunrisers Hyderabad   Hyderabad
# 54280   Royal Challengers Bangalore        Kolkata Knight Riders   Bangalore
# 115909        Kolkata Knight Riders          Sunrisers Hyderabad       Delhi
# 107035          Chennai Super Kings              Kings XI Punjab  Chandigarh
# 70175   Royal Challengers Bangalore             Delhi Daredevils   Bangalore
#
#         runs_left  balls_left  wickets_left  target_runs       crr        rrr
# 128264      160.0         114            10        168.0  8.000000   8.421053
# 189548       35.0          13             6        190.0  8.691589  16.153846
# 100819      100.0           7             2        193.0  4.938053  85.714286
# 108772       84.0         109            10         99.0  8.181818   4.623853
# 97148        94.0          58             9        165.0  6.870968   9.724138
# ...           ...         ...           ...          ...       ...        ...
# 118803      144.0         104             9        160.0  6.000000   8.307692
# 54280       108.0          52             5        166.0  5.117647  12.461538
# 115909      115.0          82             9        163.0  7.578947   8.414634
# 107035       44.0          50             8        131.0  7.457143   5.280000
# 70175       152.0         119            10        153.0  6.000000   7.663866
#
# [72055 rows x 9 columns]

# %%
# Apply the column transformer to the categorical variable


from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

trf = ColumnTransformer([
    ('trf',OneHotEncoder(sparse_output=False,handle_unknown='ignore'),['batting_team','bowling_team','city'])
]
,remainder='passthrough')

# %%
# we will use the Logistic Regression model as it gives the result based on probability

from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline

# %%
pipe = Pipeline(steps=[
    ('step1',trf),
    ('step2',LogisticRegression(solver='liblinear'))
])

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('step2', LogisticRegression(solver='liblinear'))])

# %%
# Predicting the result for test dataset

y_pred = pipe.predict(X_test)

# %%
#Checking the accuracy of the model

from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.8145886532696791

# %%
# Lets check for 10th row.
pipe.predict_proba(X_test)[10]
# Out:
# array([0.61995029, 0.38004971])

# %% [markdown]
# ## exporting the file

# %%
import pickle
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
teams
# Out:
# ['Sunrisers Hyderabad',
#  'Mumbai Indians',
#  'Royal Challengers Bangalore',
#  'Kolkata Knight Riders',
#  'Kings XI Punjab',
#  'Chennai Super Kings',
#  'Rajasthan Royals',
#  'Delhi Capitals']

# %%
delivery_df['city'].unique()
# Out:
# array(['Bangalore', 'Chandigarh', 'Delhi', 'Mumbai', 'Kolkata', 'Jaipur',
#        'Hyderabad', 'Chennai', 'Cape Town', 'Port Elizabeth', 'Durban',
#        'Centurion', 'East London', 'Johannesburg', 'Kimberley',
#        'Bloemfontein', 'Ahmedabad', 'Cuttack', 'Nagpur', 'Dharamsala',
#        'Visakhapatnam', 'Pune', 'Raipur', 'Ranchi', 'Abu Dhabi', nan,
#        'Bengaluru', 'Indore', 'Dubai', 'Sharjah', 'Navi Mumbai',
#        'Guwahati'], dtype=object)

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.5.1
